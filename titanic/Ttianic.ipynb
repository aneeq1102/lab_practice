# %%
import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv('D:/sem6/ML/lab test practice/titanic/train.csv')
df_test = pd.read_csv('D:/sem6/ML/lab test practice/titanic/test.csv')
df_doa = pd.read_csv('D:/sem6\ML/lab test practice/titanic/gender_submission.csv')

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
help(model.fit)
# Out:
# Help on method fit in module sklearn.naive_bayes:
#
# fit(X, y, sample_weight=None) method of sklearn.naive_bayes.GaussianNB instance
#     Fit Gaussian Naive Bayes according to X, y.
#
#     Parameters
#     ----------
#     X : array-like of shape (n_samples, n_features)
#         Training vectors, where `n_samples` is the number of samples
#         and `n_features` is the number of features.
#
#     y : array-like of shape (n_samples,)
#         Target values.
#
#     sample_weight : array-like of shape (n_samples,), default=None
#         Weights applied to individual samples (1. for unweighted).
#
#         .. versionadded:: 0.17
#            Gaussian Naive Bayes supports fitting with *sample_weight*.
#
#     Returns
#     -------
#     self : object
#         Returns the instance itself.

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.drop(['Name','Ticket'],axis=1,inplace=True)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Cabin        204 non-null    object
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
df_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
imp = SipmleImputer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 imp = SipmleImputer()
#
# NameError: name 'SipmleImputer' is not defined

# %%
imp = SimpleImputer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 imp = SimpleImputer()
#
# NameError: name 'SimpleImputer' is not defined

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer()

# %%
df_train['Age'] = imp.fit_transform(df_train['Age'].values.reshape(-1,1))

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Cabin        204 non-null    object
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
df_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
imp = SimpleImputer()

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
help(OneHotEncoder)
# Out:
# Help on class OneHotEncoder in module sklearn.preprocessing._encoders:
#
# class OneHotEncoder(_BaseEncoder)
#  |  OneHotEncoder(*, categories='auto', drop=None, sparse=True, dtype=<class 'numpy.float64'>, handle_unknown='error')
#  |
#  |  Encode categorical features as a one-hot numeric array.
#  |
#  |  The input to this transformer should be an array-like of integers or
#  |  strings, denoting the values taken on by categorical (discrete) features.
#  |  The features are encoded using a one-hot (aka 'one-of-K' or 'dummy')
#  |  encoding scheme. This creates a binary column for each category and
#  |  returns a sparse matrix or dense array (depending on the ``sparse``
#  |  parameter)
#  |
#  |  By default, the encoder derives the categories based on the unique values
#  |  in each feature. Alternatively, you can also specify the `categories`
#  |  manually.
#  |
#  |  This encoding is needed for feeding categorical data to many scikit-learn
# ...

# %%
df_train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df_train['Embarked']= df_train['Embarked'].fillna('S')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Cabin        204 non-null    object
#  9   Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
df_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df_train.drop(['Cabin'],axis=1,inplace=True)

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oh_encoder = OneHotEncoder(handle_unknown='ignore',sparse='False')

# %%
df_train['Embarked'] =  pd.DataFrame(oh_encoder.fit_transform(df_train['Embarked']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 df_train['Embarked'] =  pd.DataFrame(oh_encoder.fit_transform(df_train['Embarked']))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:488, in OneHotEncoder.fit_transform(self, X, y)
#     466 """
#     467 Fit OneHotEncoder to X, then transform X.
#     468
#    (...)
#     485     returned.
#     486 """
#     487 self._validate_keywords()
# --> 488 return super().fit_transform(X, y)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#         Embarked
# 0    (0, 2)\t1.0
# 1    (0, 0)\t1.0
# 2    (0, 2)\t1.0
# 3    (0, 2)\t1.0
# 4    (0, 2)\t1.0

# %%
df_train.drop(['Embarked'],axis=1,inplace=True)

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500

# %%
df_train.Sex = [1 if i=='male' else 0 for i in df_train.Sex]

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    1  22.0      1      0   7.2500
# 1            2         1       1    0  38.0      1      0  71.2833
# 2            3         1       3    0  26.0      0      0   7.9250
# 3            4         1       1    0  35.0      1      0  53.1000
# 4            5         0       3    1  35.0      0      0   8.0500

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare'],
#       dtype='object')

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    1  22.0      1      0   7.2500
# 1            2         1       1    0  38.0      1      0  71.2833
# 2            3         1       3    0  26.0      0      0   7.9250
# 3            4         1       1    0  35.0      1      0  53.1000
# 4            5         0       3    1  35.0      0      0   8.0500

# %%
y = df_train.values.reshape(-1,1)
X = df_train.drop(['Survived'],axis=1)

# %%
model = GaussianNB()
